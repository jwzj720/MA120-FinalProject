# %% [markdown]
# # High level goals - visualize word2vecs with PCAs
# # Print a word2vec's vecotor and a word similar to it - describe what their attributes mean

# %%
import gensim.downloader as api

# %%
wv = api.load('word2vec-google-news-300')
# Out:
#   Cell In[12], line 1
#     wv = api.load('word2vec-google-news-300'
#                                             ^
# SyntaxError: unexpected EOF while parsing

# %%
print(type(wv))
# Out:
# <class 'str'>

# %%
pairs = [
    ('car', 'minivan'),   # a minivan is a kind of car
    ('car', 'bicycle'),   # still a wheeled vehicle
    ('car', 'airplane'),  # ok, no wheels, but still a vehicle
    ('car', 'cereal'),    # ... and so on
    ('car', 'communism'),
]
for w1, w2 in pairs:
    print('%r\t%r\t%.2f' % (w1, w2, wv.similarity(w1, w2)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 9
#       1 pairs = [
#       2     ('car', 'minivan'),   # a minivan is a kind of car
#       3     ('car', 'bicycle'),   # still a wheeled vehicle
#    (...)
#       6     ('car', 'communism'),
#       7 ]
#       8 for w1, w2 in pairs:
# ----> 9     print('%r\t%r\t%.2f' % (w1, w2, wv.similarity(w1, w2)))
#
# AttributeError: 'str' object has no attribute 'similarity'
